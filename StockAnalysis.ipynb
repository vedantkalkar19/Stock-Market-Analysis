# %%
import pandas_datareader.data as web
import yfinance as yf
import datetime
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np 
# %matplotlib inline

# %%
start = datetime.datetime(2020,1,1)
end = datetime.datetime(2020,4,19)

# %%
google = yf.download('GOOGL',start,end)

google
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  67.420502  68.433998  67.324501  68.433998  68.433998  27278000
# 2020-01-03  67.400002  68.687500  67.365997  68.075996  68.075996  23408000
# 2020-01-06  67.581497  69.916000  67.550003  69.890503  69.890503  46768000
# 2020-01-07  70.023003  70.175003  69.578003  69.755501  69.755501  34330000
# 2020-01-08  69.740997  70.592499  69.631500  70.251999  70.251999  35314000
# ...               ...        ...        ...        ...        ...       ...
# 2020-04-13  60.075001  60.726002  59.116501  60.520500  60.520500  38702000
# 2020-04-14  61.998501  63.787498  61.426998  63.261501  63.261501  63358000
# 2020-04-15  62.325500  63.755501  61.700001  62.865002  62.865002  42236000
# 2020-04-16  63.356998  63.667999  61.910000  62.871498  62.871498  57896000
# ...

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  67.420502  68.433998  67.324501  68.433998  68.433998  27278000
# 2020-01-03  67.400002  68.687500  67.365997  68.075996  68.075996  23408000
# 2020-01-06  67.581497  69.916000  67.550003  69.890503  69.890503  46768000
# 2020-01-07  70.023003  70.175003  69.578003  69.755501  69.755501  34330000
# 2020-01-08  69.740997  70.592499  69.631500  70.251999  70.251999  35314000

# %%
fig, ax = plt.subplots()

ax.plot(google['Open'], label='GOOGL open price')
ax.plot(google['Close'], label='GOOGL close price')
ax.plot(google['High'], label = 'GOOGL High price')
ax.plot(google['Low'],  label = 'GOOGL Low price')

ax.set_xlabel('Date')
ax.set_ylabel(' Stock Price')
ax.legend()
plt.title("Google stock prices")
plt.show()

# %%
google['Volume'].plot(figsize=(17,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla = yf.download('TSLA',start,end)

tesla
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500
# ...               ...        ...        ...        ...        ...        ...
# 2020-04-13  39.344002  43.466667  38.702000  43.396667  43.396667  337131000
# 2020-04-14  46.598000  49.458668  46.161999  47.326000  47.326000  458647500
# 2020-04-15  49.466667  50.208668  47.333332  48.655334  48.655334  353655000
# 2020-04-16  47.796001  50.630001  47.114666  49.680668  49.680668  309868500
# ...

# %%
ford = yf.download('F',start,end)
ford
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2020-01-02  9.29  9.42  9.19   9.42   8.077004  43425700
# 2020-01-03  9.31  9.37  9.15   9.21   7.896945  45040800
# 2020-01-06  9.10  9.17  9.06   9.16   7.854072  43372300
# 2020-01-07  9.20  9.25  9.12   9.25   7.931241  44984100
# 2020-01-08  9.23  9.30  9.17   9.25   7.931241  45994900
# ...          ...   ...   ...    ...        ...       ...
# 2020-04-13  5.43  5.43  5.02   5.16   4.499591  99320000
# 2020-04-14  5.27  5.44  5.16   5.29   4.612952  74877000
# 2020-04-15  5.06  5.14  4.95   5.03   4.386229  74727700
# 2020-04-16  5.06  5.07  4.89   4.94   4.307748  58951200
# 2020-04-17  5.17  5.28  5.03   5.12   4.464710  91989300
#
# [74 rows x 6 columns]

# %%
gm = yf.download('GM',start,end)
gm
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  37.000000  37.380001  36.549999  37.380001  36.373829   7454400
# 2020-01-03  36.730000  36.919998  36.110001  36.320000  35.342361   9173000
# 2020-01-06  35.950001  36.180000  35.799999  35.840000  34.875282   8408200
# 2020-01-07  35.750000  35.840000  34.740002  35.150002  34.203854  17556800
# 2020-01-08  35.040001  35.200001  34.410000  34.650002  33.717316  13229400
# ...               ...        ...        ...        ...        ...       ...
# 2020-04-13  24.040001  24.100000  22.719999  23.010000  22.663776  14802600
# 2020-04-14  23.600000  23.770000  22.670000  22.980000  22.634224  12654700
# 2020-04-15  21.920000  22.270000  21.469999  21.660000  21.334089  12760900
# 2020-04-16  21.639999  21.650000  20.559999  20.870001  20.555977  11501700
# ...

# %%
tesla.to_csv('Tesla_stock.csv')
ford.to_csv('Ford_stock.csv')
gm.to_csv('GM_stock.csv')

# %%
tesla['Open'].plot(label='tesla')
gm['Open'].plot(label='gm')
ford['Open'].plot(label='ford')
plt.legend()
plt.ylabel('Stock Price')
# Out:
# Text(0, 0.5, 'Stock Price')

# %%
tesla['Volume'].plot(label='tesla')
gm['Volume'].plot(label='gm')
ford['Volume'].plot(label='ford')
plt.legend()

# %%
tesla.iloc[[tesla['Volume'].argmax()]]
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-02-04  58.863998  64.599335  55.591999  59.137333  59.137333  914082000

# %%
tesla.iloc[4:10]['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#market cap
tesla['Total Traded'] = tesla['Open'] * tesla['Volume']
gm['Total Traded'] = gm['Open'] * gm['Volume']
ford['Total Traded'] = ford['Open'] * ford['Volume']

tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500  \
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500
#
#             Total Traded
# Date
# 2020-01-02  4.046376e+09
# 2020-01-03  7.831429e+09
# 2020-01-06  4.463283e+09
# 2020-01-07  8.250801e+09
# 2020-01-08  1.475305e+10

# %%
gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  37.000000  37.380001  36.549999  37.380001  36.373829   7454400  \
# 2020-01-03  36.730000  36.919998  36.110001  36.320000  35.342361   9173000
# 2020-01-06  35.950001  36.180000  35.799999  35.840000  34.875282   8408200
# 2020-01-07  35.750000  35.840000  34.740002  35.150002  34.203854  17556800
# 2020-01-08  35.040001  35.200001  34.410000  34.650002  33.717316  13229400
#
#             Total Traded
# Date
# 2020-01-02  2.758128e+08
# 2020-01-03  3.369243e+08
# 2020-01-06  3.022748e+08
# 2020-01-07  6.276556e+08
# 2020-01-08  4.635582e+08

# %%
ford.head()
# Out:
#             Open  High   Low  Close  Adj Close    Volume  Total Traded
# Date
# 2020-01-02  9.29  9.42  9.19   9.42   8.077004  43425700  4.034248e+08
# 2020-01-03  9.31  9.37  9.15   9.21   7.896945  45040800  4.193299e+08
# 2020-01-06  9.10  9.17  9.06   9.16   7.854072  43372300  3.946879e+08
# 2020-01-07  9.20  9.25  9.12   9.25   7.931241  44984100  4.138537e+08
# 2020-01-08  9.23  9.30  9.17   9.25   7.931241  45994900  4.245329e+08

# %%
tesla['Total Traded'].plot(label= 'tesla', figsize=(15,7))
gm['Total Traded'].plot(label='gm')
ford['Total Traded'].plot(label='ford')

plt.legend()

# %%
tesla['Total Traded'].argmax()
# Out:
# 22

# %%
tesla.iloc[[tesla['Total Traded'].argmax()]]
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-02-04  58.863998  64.599335  55.591999  59.137333  59.137333  914082000  \
#
#             Total Traded
# Date
# 2020-02-04  5.380652e+10

# %% [markdown]
# # moving Average

# %%
gm['Open'].plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
gm['MA50'] = gm['Open'].rolling(50).mean()

gm['MA50'].plot(label='MA50')
plt.legend()

# %% [markdown]
# Scatter MATRIX AND CORRELATION

# %%
from pandas.plotting import scatter_matrix

# %%
car_comp = pd.concat([tesla['Open'],gm['Open'],ford['Open']],axis = 1)
car_comp.columns = ['Tesla Open', 'GM Open', 'Ford Open']

# %%
scatter_matrix(car_comp, hist_kwds={'bins':30})
# Out:
# array([[<AxesSubplot:xlabel='Tesla Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Tesla Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Tesla Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='GM Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='GM Open'>],
#        [<AxesSubplot:xlabel='Tesla Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='GM Open', ylabel='Ford Open'>,
#         <AxesSubplot:xlabel='Ford Open', ylabel='Ford Open'>]],
#       dtype=object)

# %% [markdown]
# Charts

# %%
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, date2num, WeekdayLocator, MONDAY, DayLocator

# Assuming you have 'ford' DataFrame defined with the necessary data

ford_reset = ford.loc['2020-01': '2020-01'].reset_index()

ford_reset['date_ax'] = ford_reset['Date'].apply(lambda date: date2num(date))
ford_values = [tuple(vals) for vals in ford_reset[['date_ax', 'Open', 'High', 'Low', 'Close']].values]

mondays = WeekdayLocator(MONDAY)
alldays = DayLocator()
weekFormatter = DateFormatter('%b %d')
dayFormatter = DateFormatter('%d')

fig, ax = plt.subplots()

ax.xaxis_date()
ax.xaxis.set_major_locator(mondays)
ax.xaxis.set_minor_locator(alldays)
ax.xaxis.set_major_formatter(weekFormatter)

candlestick_ohlc(ax, ford_values, width=0.6, colorup='g', colordown='r')

plt.show()

# %% [markdown]
# DAILY PERCENTAGE CHANGE

# %%
tesla['return'] = (tesla['Close']/ tesla['Close'].shift(1)) - 1

tesla.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500  \
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500
#
#             Total Traded    return
# Date
# 2020-01-02  4.046376e+09       NaN
# 2020-01-03  7.831429e+09  0.029633
# 2020-01-06  4.463283e+09  0.019255
# 2020-01-07  8.250801e+09  0.038801
# 2020-01-08  1.475305e+10  0.049205

# %%
ford['return'] = (ford['Close']/ ford['Close'].shift(1)) - 1

ford.head()
# Out:
#             Open  High   Low  Close  Adj Close    Volume  Total Traded
# Date
# 2020-01-02  9.29  9.42  9.19   9.42   8.077004  43425700  4.034248e+08  \
# 2020-01-03  9.31  9.37  9.15   9.21   7.896945  45040800  4.193299e+08
# 2020-01-06  9.10  9.17  9.06   9.16   7.854072  43372300  3.946879e+08
# 2020-01-07  9.20  9.25  9.12   9.25   7.931241  44984100  4.138537e+08
# 2020-01-08  9.23  9.30  9.17   9.25   7.931241  45994900  4.245329e+08
#
#               return
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.022293
# 2020-01-06 -0.005429
# 2020-01-07  0.009825
# 2020-01-08  0.000000

# %%
gm['return'] = (gm['Close']/ gm['Close'].shift(1)) - 1

gm.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-01-02  37.000000  37.380001  36.549999  37.380001  36.373829   7454400  \
# 2020-01-03  36.730000  36.919998  36.110001  36.320000  35.342361   9173000
# 2020-01-06  35.950001  36.180000  35.799999  35.840000  34.875282   8408200
# 2020-01-07  35.750000  35.840000  34.740002  35.150002  34.203854  17556800
# 2020-01-08  35.040001  35.200001  34.410000  34.650002  33.717316  13229400
#
#             Total Traded    return
# Date
# 2020-01-02  2.758128e+08       NaN
# 2020-01-03  3.369243e+08 -0.028357
# 2020-01-06  3.022748e+08 -0.013216
# 2020-01-07  6.276556e+08 -0.019252
# 2020-01-08  4.635582e+08 -0.014225

# %%
ford['return'].hist(bins=60,label='ford')
tesla['return'].hist(bins=60,label='tesla')
gm['return'].hist(bins=60,label='gm')

plt.legend()

# %%
ford['return'].plot(kind='kde',label='ford')
tesla['return'].plot(kind='kde',label='tesla')
gm['return'].plot(kind='kde',label='gm')

plt.legend()

# %%
box_df = pd.concat([tesla['return'],gm['return'],ford['return']],axis=1)

box_df.columns = ['tesla return','gm return','ford return']

box_df.plot(kind='box', figsize=(15,7))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df, hist_kwds={'bins': 50}, alpha=0.5)
# Out:
# array([[<AxesSubplot:xlabel='tesla return', ylabel='tesla return'>,
#         <AxesSubplot:xlabel='gm return', ylabel='tesla return'>,
#         <AxesSubplot:xlabel='ford return', ylabel='tesla return'>],
#        [<AxesSubplot:xlabel='tesla return', ylabel='gm return'>,
#         <AxesSubplot:xlabel='gm return', ylabel='gm return'>,
#         <AxesSubplot:xlabel='ford return', ylabel='gm return'>],
#        [<AxesSubplot:xlabel='tesla return', ylabel='ford return'>,
#         <AxesSubplot:xlabel='gm return', ylabel='ford return'>,
#         <AxesSubplot:xlabel='ford return', ylabel='ford return'>]],
#       dtype=object)

# %% [markdown]
# Cumulative Return

# %%
tesla['comulative return'] = (1 + tesla['return']).cumprod()
ford['comulative return'] = (1 + ford['return']).cumprod()
gm['comulative return'] = (1 + gm['return']).cumprod()

# %%
tesla['comulative return'].plot(label='tesla')
ford['comulative return'].plot(label='ford')
gm['comulative return'].plot(label='gm')
plt.legend()
plt.title("Cumulative Return")
# Out:
# Text(0.5, 1.0, 'Cumulative Return')

# %% [markdown]
# Conclusion

# %% [markdown]
# Comprehensive introduction to stock market analysis by using differnt ploting charts and visualization of the stock prices.
